# %% [markdown]
# <a href="https://colab.research.google.com/github/athiniotim/Final_Essay_Forest_Fires/blob/main/forest_fires_kathimerini_articles_wordcloud_Michaela_Athinioti.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %% [markdown]
# ### Άνοιγμα csv αρχείου που βρίσκεται στο gdrive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
fires_df = pd.read_csv("/content/drive/MyDrive/Final Essay ΕΔΔΕ.2 Αθηνιώτη Μιχαέλα/clean csv/forest_fires_kathimerini_articles_csv")
fires_df.head()
# Out:
#                                          article_url  \
# 0  https://www.kathimerini.gr/world/563396869/oie...
# 1  https://www.kathimerini.gr/life/environment/56...
# 2  https://www.kathimerini.gr/life/environment/56...
# 3  https://www.kathimerini.gr/world/563358376/por...
# 4  https://www.kathimerini.gr/society/563356729/d...
#
#                                                title        date      time  \
# 0  ΟΗΕ: Το 2024, η κλιματική αλλαγή προκάλεσε ακρ...  2024-12-30  23:42:00
# 1                                                NaN         NaN       NaN
# 2                                                NaN         NaN       NaN
# 3  Πορτογαλία και Ισπανία έζησαν τον πιο ζεστό Νο...  2024-12-05  22:11:00
# 4   Δύο νέες πλατφόρμες για την ανάλυση του κλίματος  2024-12-05  23:34:00
#
#     section           author  \
# 0    Κόσμος         Newsroom
# 1       NaN              NaN
# 2       NaN              NaN
# 3    Κόσμος         Newsroom
# 4  Κοινωνία  Γιάννης Ελαφρός
#
#                                              excerpt  \
# 0  Σύμφωνα με τον Παγκόσμιο Μετεωρολογικό Οργανισ...
# 1                                                NaN
# 2                                                NaN
# 3  Η μέση θερμοκρασία του Νοεμβρίου στην Πορτογαλ...
# 4  Δύο νέους ψηφιακούς κόμβους ανάλυσης της ατμόσ...
#
#                                            text_body  \
# 0  Η κλιματική αλλαγή προκάλεσε ακραίες μετεωρολο...
# 1  Από το μικρό γαλλικό αρχιπέλαγος της Μαγιότ έω...
# 2  Δύσκολες κλιματολογικές συνθήκες, νέες προκλήσ...
# 3  Υψηλότατες για την εποχή θερμοκρασίες καταγράφ...
# 4  Δύο νέα ισχυρά εργαλεία καταγραφής, ανάλυσης κ...
#
#                                        feat_img_link  \
# 0  https://www.kathimerini.gr/wp-content/uploads/...
# 1                                                NaN
# 2                                                NaN
# 3  https://www.kathimerini.gr/wp-content/uploads/...
# 4  https://www.kathimerini.gr/wp-content/uploads/...
#
#                                      feat_img_cation
# 0  Καλιφόρνια: Προειδοποίηση στους κατοίκους να μ...
# 1                                                NaN
# 2                                                NaN
# 3                                       Shutterstock
# 4                   Φωτ. INTIME/ ΧΑΛΚΙΟΠΟΥΛΟΣ ΝΙΚΟΣ.

# %%
fires_df.shape
# Out:
# (648, 10)

# %%
fires_df.sort_values("date")
# Out:
#                                            article_url  \
# 647  https://www.kathimerini.gr/world/562211257/isp...
# 646  https://www.kathimerini.gr/world/562215640/kal...
# 644  https://www.kathimerini.gr/world/562221523/cop...
# 643  https://www.kathimerini.gr/world/562221718/kal...
# 645  https://www.kathimerini.gr/world/562221112/vra...
# ..                                                 ...
# 571  https://www.kathimerini.gr/investigations/spec...
# 572  https://www.kathimerini.gr/investigations/spec...
# 573  https://www.kathimerini.gr/investigations/spec...
# 612  https://www.kathimerini.gr/life/environment/56...
# 620  https://www.kathimerini.gr/life/health/5623767...
#
#                                                  title        date      time  \
# 647  Ισπανία: Το 2022 ήταν η θερμότερη χρονιά που έ...  2023-01-02  22:47:10
# 646  Καλιφόρνια – Κακοκαιρία: Ένα νεκρό παιδί, χιλι...  2023-01-05  18:02:52
# 644  Copernicus: Το 2022 ήταν το δεύτερο πιο ζεστό ...  2023-01-10  15:53:30
# 643  Καλιφόρνια: Τουλάχιστον 14 νεκροί από τη σφοδρ...  2023-01-10  17:27:40
# 645  Βραζιλία: Οι ρίζες της εξέγερσης των μπολσοναρ...  2023-01-10  12:24:33
# ..                                                 ...         ...       ...
# 571                                                NaN         NaN       NaN
# 572                                                NaN         NaN       NaN
# 573                                                NaN         NaN       NaN
# 612                                                NaN         NaN       NaN
# 620                                                NaN         NaN       NaN
#
#     section             author  \
# 647  Κόσμος           Newsroom
# 646  Κόσμος           Newsroom
# 644  Κόσμος           Newsroom
# 643  Κόσμος           Newsroom
# 645  Κόσμος  Δημήτρης Αθηνάκης
# ..      ...                ...
# 571     NaN                NaN
# 572     NaN                NaN
# 573     NaN                NaN
# 612     NaN                NaN
# 620     NaN                NaN
#
#                                                excerpt  \
# 647                                                NaN
# 646  Περισσότερες από 180.000 κατοικίες και επιχειρ...
# 644  «Ζούμε ήδη τις καταστροφικές συνέπειες του θερ...
# 643  «Τα θύματα είναι περισσότερα από εκείνα που σκ...
# 645  Τα σχέδια του προέδρου Λούλα για την προστασία...
# ..                                                 ...
# 571                                                NaN
# 572                                                NaN
# 573                                                NaN
# 612                                                NaN
# 620                                                NaN
#
#                                              text_body  \
# 647  Η Ισπανία γνώρισε το 2022 τη θερμότερη χρονιά ...
# 646  Ένα παιδί σκοτώθηκε και δεκάδες χιλιάδες άνθρω...
# 644  Το 2022 ήταν το δεύτερο πιο ζεστό έτος που έχε...
# 643  Σφοδρή βροχόπτωση αναμένεται να πλήξει και πάλ...
# 645  Στα πρώτα σχόλιά του μετά την επίθεση, ο νέος ...
# ..                                                 ...
# 571  Είναι δυνατόν το λιώσιμο των πάγων στην Αρκτικ...
# 572  «Είναι μια εξαιρετικά θερμή μέρα στην Αθήνα, α...
# 573  Καθώς o Καναδάς εξακολουθεί να φλέγεται εδώ κα...
# 612  Προδιαγεγραμμένη Καύση – Μία μέθοδος που μπορε...
# 620  Εκτός κι αν τύχει να εισπνεύσετε τα καυσαέρια ...
#
#                                          feat_img_link  \
# 647  https://www.kathimerini.gr/wp-content/uploads/...
# 646  https://www.kathimerini.gr/wp-content/uploads/...
# 644  https://www.kathimerini.gr/wp-content/uploads/...
# 643  https://www.kathimerini.gr/wp-content/uploads/...
# 645  https://www.kathimerini.gr/wp-content/uploads/...
# ..                                                 ...
# 571                                                NaN
# 572                                                NaN
# 573                                                NaN
# 612                                                NaN
# 620                                                NaN
#
#                                        feat_img_cation
# 647                                       shutterstock
# 646                              REUTERS/Carlos Barria
# 644                            Φωτ. AP/ Michael Probst
# 643                          Φωτ. REUTERS/ Erica Urech
# 645  Προεκλογική πινακίδα υπέρ του πρώην προέδρου τ...
# ..                                                 ...
# 571                                                NaN
# 572                                                NaN
# 573                                                NaN
# 612                                                NaN
# 620                                                NaN
#
# [648 rows x 10 columns]

# %%
fires_df.sort_values("date", ascending=False).reset_index(drop=True)
# Out:
#                                            article_url  \
# 0    https://www.kathimerini.gr/world/563396869/oie...
# 1    https://www.kathimerini.gr/society/563356729/d...
# 2    https://www.kathimerini.gr/world/563358376/por...
# 3    https://www.kathimerini.gr/life/science/563344...
# 4    https://www.kathimerini.gr/economy/563327200/e...
# ..                                                 ...
# 643  https://www.kathimerini.gr/investigations/spec...
# 644  https://www.kathimerini.gr/investigations/spec...
# 645  https://www.kathimerini.gr/investigations/spec...
# 646  https://www.kathimerini.gr/life/environment/56...
# 647  https://www.kathimerini.gr/life/health/5623767...
#
#                                                  title        date      time  \
# 0    ΟΗΕ: Το 2024, η κλιματική αλλαγή προκάλεσε ακρ...  2024-12-30  23:42:00
# 1     Δύο νέες πλατφόρμες για την ανάλυση του κλίματος  2024-12-05  23:34:00
# 2    Πορτογαλία και Ισπανία έζησαν τον πιο ζεστό Νο...  2024-12-05  22:11:00
# 3    Ερευνα: Η ατμοσφαιρική ρύπανση από τις πυρκαγι...  2024-11-28  10:32:22
# 4    Ερρίκος Μοάτσος: Μεγάλο το κενό προστασίας από...  2024-11-25  13:58:00
# ..                                                 ...         ...       ...
# 643                                                NaN         NaN       NaN
# 644                                                NaN         NaN       NaN
# 645                                                NaN         NaN       NaN
# 646                                                NaN         NaN       NaN
# 647                                                NaN         NaN       NaN
#
#                                         section           author  \
# 0                                        Κόσμος         Newsroom
# 1                                      Κοινωνία  Γιάννης Ελαφρός
# 2                                        Κόσμος         Newsroom
# 3                                      Επιστήμη         Newsroom
# 4    Διευθύνων σύμβουλος  της ERGO Ασφαλιστικής  Ευγενία Τζώρτζη
# ..                                          ...              ...
# 643                                         NaN              NaN
# 644                                         NaN              NaN
# 645                                         NaN              NaN
# 646                                         NaN              NaN
# 647                                         NaN              NaN
#
#                                                excerpt  \
# 0    Σύμφωνα με τον Παγκόσμιο Μετεωρολογικό Οργανισ...
# 1    Δύο νέους ψηφιακούς κόμβους ανάλυσης της ατμόσ...
# 2    Η μέση θερμοκρασία του Νοεμβρίου στην Πορτογαλ...
# 3    Η έρευνα δημοσιεύτηκε στο επιστημονικό περιοδι...
# 4    Ασφαλιστική κάλυψη διαθέτουν μόλις το 18% των ...
# ..                                                 ...
# 643                                                NaN
# 644                                                NaN
# 645                                                NaN
# 646                                                NaN
# 647                                                NaN
#
#                                              text_body  \
# 0    Η κλιματική αλλαγή προκάλεσε ακραίες μετεωρολο...
# 1    Δύο νέα ισχυρά εργαλεία καταγραφής, ανάλυσης κ...
# 2    Υψηλότατες για την εποχή θερμοκρασίες καταγράφ...
# 3    Η ατμοσφαιρική ρύπανση που προκαλείται από τις...
# 4    Μόλις το ένα τρίτο των επιχειρήσεων με τουλάχι...
# ..                                                 ...
# 643  Είναι δυνατόν το λιώσιμο των πάγων στην Αρκτικ...
# 644  «Είναι μια εξαιρετικά θερμή μέρα στην Αθήνα, α...
# 645  Καθώς o Καναδάς εξακολουθεί να φλέγεται εδώ κα...
# 646  Προδιαγεγραμμένη Καύση – Μία μέθοδος που μπορε...
# 647  Εκτός κι αν τύχει να εισπνεύσετε τα καυσαέρια ...
#
#                                          feat_img_link  \
# 0    https://www.kathimerini.gr/wp-content/uploads/...
# 1    https://www.kathimerini.gr/wp-content/uploads/...
# 2    https://www.kathimerini.gr/wp-content/uploads/...
# 3    https://www.kathimerini.gr/wp-content/uploads/...
# 4    https://www.kathimerini.gr/wp-content/uploads/...
# ..                                                 ...
# 643                                                NaN
# 644                                                NaN
# 645                                                NaN
# 646                                                NaN
# 647                                                NaN
#
#                                        feat_img_cation
# 0    Καλιφόρνια: Προειδοποίηση στους κατοίκους να μ...
# 1                     Φωτ. INTIME/ ΧΑΛΚΙΟΠΟΥΛΟΣ ΝΙΚΟΣ.
# 2                                         Shutterstock
# 3                               Φωτ. AP/ Sergio Azenha
# 4    Η ERGO Ασφαλιστική, θυγατρική του διεθνούς ασφ...
# ..                                                 ...
# 643                                                NaN
# 644                                                NaN
# 645                                                NaN
# 646                                                NaN
# 647                                                NaN
#
# [648 rows x 10 columns]

# %%
#άρα δεν υπάρχει πρόβλημα

# %%
fires_df[fires_df['date'].isnull()] #αναζητώ rows με missing values
# Out:
#                                            article_url title date time  \
# 1    https://www.kathimerini.gr/life/environment/56...   NaN  NaN  NaN
# 2    https://www.kathimerini.gr/life/environment/56...   NaN  NaN  NaN
# 5    https://www.kathimerini.gr/visual/infographics...   NaN  NaN  NaN
# 10   https://www.kathimerini.gr/visual/infographics...   NaN  NaN  NaN
# 11   https://www.kathimerini.gr/society/reportaz/56...   NaN  NaN  NaN
# ..                                                 ...   ...  ...  ...
# 571  https://www.kathimerini.gr/investigations/spec...   NaN  NaN  NaN
# 572  https://www.kathimerini.gr/investigations/spec...   NaN  NaN  NaN
# 573  https://www.kathimerini.gr/investigations/spec...   NaN  NaN  NaN
# 612  https://www.kathimerini.gr/life/environment/56...   NaN  NaN  NaN
# 620  https://www.kathimerini.gr/life/health/5623767...   NaN  NaN  NaN
#
#     section author excerpt                                          text_body  \
# 1       NaN    NaN     NaN  Από το μικρό γαλλικό αρχιπέλαγος της Μαγιότ έω...
# 2       NaN    NaN     NaN  Δύσκολες κλιματολογικές συνθήκες, νέες προκλήσ...
# 5       NaN    NaN     NaN  Τα έργα τα οποία προκρίνει η Περιφέρεια Αττική...
# 10      NaN    NaN     NaN  Την ικανοποιητική, αλλά αναποτελεσματική πρόοδ...
# 11      NaN    NaN     NaN  Η πρόσφατη βιβλική καταστροφή στη Βαλένθια εξα...
# ..      ...    ...     ...                                                ...
# 571     NaN    NaN     NaN  Είναι δυνατόν το λιώσιμο των πάγων στην Αρκτικ...
# 572     NaN    NaN     NaN  «Είναι μια εξαιρετικά θερμή μέρα στην Αθήνα, α...
# 573     NaN    NaN     NaN  Καθώς o Καναδάς εξακολουθεί να φλέγεται εδώ κα...
# 612     NaN    NaN     NaN  Προδιαγεγραμμένη Καύση – Μία μέθοδος που μπορε...
# 620     NaN    NaN     NaN  Εκτός κι αν τύχει να εισπνεύσετε τα καυσαέρια ...
#
#     feat_img_link feat_img_cation
# 1             NaN             NaN
# 2             NaN             NaN
# 5             NaN             NaN
# 10            NaN             NaN
# 11            NaN             NaN
# ..            ...             ...
# 571           NaN             NaN
# 572           NaN             NaN
# 573           NaN             NaN
# 612           NaN             NaN
# 620           NaN             NaN
#
# [73 rows x 10 columns]

# %%
#διαγράφω τις γραμμές που έχουν τιμές date NaN
fires_df2 = fires_df.dropna(subset=['date'])
fires_df2
# Out:
#                                            article_url  \
# 0    https://www.kathimerini.gr/world/563396869/oie...
# 3    https://www.kathimerini.gr/world/563358376/por...
# 4    https://www.kathimerini.gr/society/563356729/d...
# 6    https://www.kathimerini.gr/life/science/563344...
# 7    https://www.kathimerini.gr/politics/563336191/...
# ..                                                 ...
# 643  https://www.kathimerini.gr/world/562221718/kal...
# 644  https://www.kathimerini.gr/world/562221523/cop...
# 645  https://www.kathimerini.gr/world/562221112/vra...
# 646  https://www.kathimerini.gr/world/562215640/kal...
# 647  https://www.kathimerini.gr/world/562211257/isp...
#
#                                                  title        date      time  \
# 0    ΟΗΕ: Το 2024, η κλιματική αλλαγή προκάλεσε ακρ...  2024-12-30  23:42:00
# 3    Πορτογαλία και Ισπανία έζησαν τον πιο ζεστό Νο...  2024-12-05  22:11:00
# 4     Δύο νέες πλατφόρμες για την ανάλυση του κλίματος  2024-12-05  23:34:00
# 6    Ερευνα: Η ατμοσφαιρική ρύπανση από τις πυρκαγι...  2024-11-28  10:32:22
# 7    Φολκέρ Τουρκ στην «Κ»: «Οι πολιτικές ελίτ αδια...  2024-11-23  22:59:00
# ..                                                 ...         ...       ...
# 643  Καλιφόρνια: Τουλάχιστον 14 νεκροί από τη σφοδρ...  2023-01-10  17:27:40
# 644  Copernicus: Το 2022 ήταν το δεύτερο πιο ζεστό ...  2023-01-10  15:53:30
# 645  Βραζιλία: Οι ρίζες της εξέγερσης των μπολσοναρ...  2023-01-10  12:24:33
# 646  Καλιφόρνια – Κακοκαιρία: Ένα νεκρό παιδί, χιλι...  2023-01-05  18:02:52
# 647  Ισπανία: Το 2022 ήταν η θερμότερη χρονιά που έ...  2023-01-02  22:47:10
#
#                 section             author  \
# 0                Κόσμος           Newsroom
# 3                Κόσμος           Newsroom
# 4              Κοινωνία    Γιάννης Ελαφρός
# 6              Επιστήμη           Newsroom
# 7    Εξωτερική Πολιτική      Βασίλης Νέδος
# ..                  ...                ...
# 643              Κόσμος           Newsroom
# 644              Κόσμος           Newsroom
# 645              Κόσμος  Δημήτρης Αθηνάκης
# 646              Κόσμος           Newsroom
# 647              Κόσμος           Newsroom
#
#                                                excerpt  \
# 0    Σύμφωνα με τον Παγκόσμιο Μετεωρολογικό Οργανισ...
# 3    Η μέση θερμοκρασία του Νοεμβρίου στην Πορτογαλ...
# 4    Δύο νέους ψηφιακούς κόμβους ανάλυσης της ατμόσ...
# 6    Η έρευνα δημοσιεύτηκε στο επιστημονικό περιοδι...
# 7    Οι «χαμένοι» της παγκοσμιοποίησης και η μεγάλη...
# ..                                                 ...
# 643  «Τα θύματα είναι περισσότερα από εκείνα που σκ...
# 644  «Ζούμε ήδη τις καταστροφικές συνέπειες του θερ...
# 645  Τα σχέδια του προέδρου Λούλα για την προστασία...
# 646  Περισσότερες από 180.000 κατοικίες και επιχειρ...
# 647                                                NaN
#
#                                              text_body  \
# 0    Η κλιματική αλλαγή προκάλεσε ακραίες μετεωρολο...
# 3    Υψηλότατες για την εποχή θερμοκρασίες καταγράφ...
# 4    Δύο νέα ισχυρά εργαλεία καταγραφής, ανάλυσης κ...
# 6    Η ατμοσφαιρική ρύπανση που προκαλείται από τις...
# 7    Η αδιαφορία των πολιτικών ελίτ για τους «χαμέν...
# ..                                                 ...
# 643  Σφοδρή βροχόπτωση αναμένεται να πλήξει και πάλ...
# 644  Το 2022 ήταν το δεύτερο πιο ζεστό έτος που έχε...
# 645  Στα πρώτα σχόλιά του μετά την επίθεση, ο νέος ...
# 646  Ένα παιδί σκοτώθηκε και δεκάδες χιλιάδες άνθρω...
# 647  Η Ισπανία γνώρισε το 2022 τη θερμότερη χρονιά ...
#
#                                          feat_img_link  \
# 0    https://www.kathimerini.gr/wp-content/uploads/...
# 3    https://www.kathimerini.gr/wp-content/uploads/...
# 4    https://www.kathimerini.gr/wp-content/uploads/...
# 6    https://www.kathimerini.gr/wp-content/uploads/...
# 7    https://www.kathimerini.gr/wp-content/uploads/...
# ..                                                 ...
# 643  https://www.kathimerini.gr/wp-content/uploads/...
# 644  https://www.kathimerini.gr/wp-content/uploads/...
# 645  https://www.kathimerini.gr/wp-content/uploads/...
# 646  https://www.kathimerini.gr/wp-content/uploads/...
# 647  https://www.kathimerini.gr/wp-content/uploads/...
#
#                                        feat_img_cation
# 0    Καλιφόρνια: Προειδοποίηση στους κατοίκους να μ...
# 3                                         Shutterstock
# 4                     Φωτ. INTIME/ ΧΑΛΚΙΟΠΟΥΛΟΣ ΝΙΚΟΣ.
# 6                               Φωτ. AP/ Sergio Azenha
# 7    «Η κλιματική κρίση δεν είναι μακριά. Είναι εδώ...
# ..                                                 ...
# 643                          Φωτ. REUTERS/ Erica Urech
# 644                            Φωτ. AP/ Michael Probst
# 645  Προεκλογική πινακίδα υπέρ του πρώην προέδρου τ...
# 646                              REUTERS/Carlos Barria
# 647                                       shutterstock
#
# [575 rows x 10 columns]

# %%
fires_df2.dtypes
# Out:
# article_url        object
# title              object
# date               object
# time               object
# section            object
# author             object
# excerpt            object
# text_body          object
# feat_img_link      object
# feat_img_cation    object
# dtype: object

# %%
fires_df2['date_dt'] = pd.to_datetime(fires_df2['date'], format='%Y-%m-%d')
fires_df2.dtypes
# Out:
# <ipython-input-12-864d8fa05a68>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fires_df2['date_dt'] = pd.to_datetime(fires_df2['date'], format='%Y-%m-%d')
# article_url                object
# title                      object
# date                       object
# time                       object
# section                    object
# author                     object
# excerpt                    object
# text_body                  object
# feat_img_link              object
# feat_img_cation            object
# date_dt            datetime64[ns]
# dtype: object

# %%
fires_df2['time_dt'] = pd.to_datetime(fires_df2['time'], format='%H:%M:%S')
# Out:
# <ipython-input-13-d6f4bba23d67>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fires_df2['time_dt'] = pd.to_datetime(fires_df2['time'], format='%H:%M:%S')

# %%
fires_df2['text'] = fires_df2['title'] + '' + fires_df2['excerpt']  + '' + fires_df2['text_body']
# Out:
# <ipython-input-14-fee96fe7d2a8>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fires_df2['text'] = fires_df2['title'] + '' + fires_df2['excerpt']  + '' + fires_df2['text_body']

# %%
shortf_df = fires_df2[['date_dt', 'text']]
shortf_df.head()
# Out:
#      date_dt                                               text
# 0 2024-12-30  ΟΗΕ: Το 2024, η κλιματική αλλαγή προκάλεσε ακρ...
# 3 2024-12-05  Πορτογαλία και Ισπανία έζησαν τον πιο ζεστό Νο...
# 4 2024-12-05  Δύο νέες πλατφόρμες για την ανάλυση του κλίματ...
# 6 2024-11-28  Ερευνα: Η ατμοσφαιρική ρύπανση από τις πυρκαγι...
# 7 2024-11-23  Φολκέρ Τουρκ στην «Κ»: «Οι πολιτικές ελίτ αδια...

# %%
shortf_df2 = shortf_df.copy()
shortf_df2['year'] = pd.DatetimeIndex(shortf_df['date_dt']).year
shortf_df2['month'] = pd.DatetimeIndex(shortf_df['date_dt']).month
shortf_df2['day'] = pd.DatetimeIndex(shortf_df['date_dt']).day
shortf_df2.head()
# Out:
#      date_dt                                               text  year  month  \
# 0 2024-12-30  ΟΗΕ: Το 2024, η κλιματική αλλαγή προκάλεσε ακρ...  2024     12
# 3 2024-12-05  Πορτογαλία και Ισπανία έζησαν τον πιο ζεστό Νο...  2024     12
# 4 2024-12-05  Δύο νέες πλατφόρμες για την ανάλυση του κλίματ...  2024     12
# 6 2024-11-28  Ερευνα: Η ατμοσφαιρική ρύπανση από τις πυρκαγι...  2024     11
# 7 2024-11-23  Φολκέρ Τουρκ στην «Κ»: «Οι πολιτικές ελίτ αδια...  2024     11
#
#    day
# 0   30
# 3    5
# 4    5
# 6   28
# 7   23

# %%
shortf_df2['date_dt'] = pd.to_datetime(shortf_df2['date_dt'])

# %%
shortf_df2.head()
# Out:
#      date_dt                                               text  year  month  \
# 0 2024-12-30  ΟΗΕ: Το 2024, η κλιματική αλλαγή προκάλεσε ακρ...  2024     12
# 3 2024-12-05  Πορτογαλία και Ισπανία έζησαν τον πιο ζεστό Νο...  2024     12
# 4 2024-12-05  Δύο νέες πλατφόρμες για την ανάλυση του κλίματ...  2024     12
# 6 2024-11-28  Ερευνα: Η ατμοσφαιρική ρύπανση από τις πυρκαγι...  2024     11
# 7 2024-11-23  Φολκέρ Τουρκ στην «Κ»: «Οι πολιτικές ελίτ αδια...  2024     11
#
#    day
# 0   30
# 3    5
# 4    5
# 6   28
# 7   23

# %%
shortf_df2.shape
# Out:
# (575, 5)

# %%
shortf_df2['month'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='month'>

# %%
#σύγκριση πλήθους δημοσιεύσεων με καταγεγραμμένες πυρκαγιές --> αντιπροσωπευτικότητα δημοσιεύσεων με τo πραγματικό πλήθος πυρκαγιών

# %%
import plotly.express as px
month_counts_df = shortf_df2['month'].value_counts().reset_index()
month_counts_df.columns = ['month', 'articles_count']
fig = px.bar(month_counts_df, x='month', y="articles_count", text_auto=True)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="a6f5f83b-7b6b-4efa-9b11-3dd0118204d1" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a6f5f83b-7b6b-4efa-9b11-3dd0118204d1")) {                    Plotly.newPlot(                        "a6f5f83b-7b6b-4efa-9b11-3dd0118204d1",                        [{"alignmentgroup":"True","hovertemplate":"month=%{x}\u003cbr\u003earticles_count=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","texttemplate":"%{y}","x":[8,7,9,6,10,4,5,2,11,3,12,1],"xaxis":"x","y":[167,143,58,35,33,28,26,24,19,18,12,12],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","m ...

# %%
month_names_el = {
    1: "Ιαν",
    2: "Φεβ",
    3: "Μαρ",
    4: "Απρ",
    5: "Μαϊ",
    6: "Ιουν",
    7: "Ιουλ",
    8: "Αυγ",
    9: "Σεπ",
    10: "Οκτ",
    11: "Νοε",
    12: "Δεκ"
}
shortf_df2['month_name'] = shortf_df2['month'].map(month_names_el)

month_counts_df = shortf_df2['month_name'].value_counts().reset_index()
month_counts_df.columns = ['month_name', 'articles_count']
fig = px.bar(month_counts_df, x='month_name', y="articles_count",
             labels={'month_name':'μήνας', 'articles_count':'πλήθος άρθρων'}, text_auto=True)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="1c8a3611-2d69-4131-a73f-975fe0e2f863" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("1c8a3611-2d69-4131-a73f-975fe0e2f863")) {                    Plotly.newPlot(                        "1c8a3611-2d69-4131-a73f-975fe0e2f863",                        [{"alignmentgroup":"True","hovertemplate":"μήνας=%{x}\u003cbr\u003eπλήθος άρθρων=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","texttemplate":"%{y}","x":["Αυγ","Ιουλ","Σεπ","Ιουν","Οκτ","Απρ","Μαϊ","Φεβ","Νοε","Μαρ","Δεκ","Ιαν"],"xaxis":"x","y":[167,143,58,35,33,28,26,24,19,18,12,12],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type" ...

# %%
from wordcloud import WordCloud, STOPWORDS
import matplotlib.pyplot as plt

# %%
aug_text = shortf_df2[shortf_df2['month']==8]['text'].str.cat(sep = ' ')
aug_text
# Out:
# 'Handelsblatt: Ζημιές δισεκατομμυρίων στην Ελλάδα λόγω της κλιματικής κρίσης«Μετά την κρίση χρέους η Ελλάδα απειλείται τώρα από την κλιματική κρίση», γράφει η οικονομική επιθεώρηση Handelsblatt. Και μία τέτοια κρίση «θα αποτελέσει μία σοβαρή οικονομική δοκιμασία για την πιο χρεωμένη χώρα της Ευρώπης»Κάθε χρόνο, ιδίως κατά τους καλοκαιρινούς μήνες, η Ελλάδα υποφέρει από εκτεταμένες δασικές πυρκαγιές, ξηρασία, καύσωνες. Οι φυσικές καταστροφές αφήνουν πίσω τους δεκάδες χιλιάδες καμένα στρέμματα γης, κατεστραμμένα σπίτια και ορισμένες φορές νεκρούς. Και πέραν αυτών έχουν και ένα τεράστιο οικονομικό κόστος για το ελληνικό κράτος. «Μετά την κρίση χρέους η Ελλάδα απειλείται τώρα από την κλιματική κρίση», γράφει η οικονομική επιθεώρηση Handelsblatt. Και μία τέτοια κρίση «θα αποτελέσει μία σοβαρή οικονομική δοκιμασία για την πιο χρεωμένη χώρα της Ευρώπης». Ο οίκος αξιολόγησης Scope εκτιμά πως το καλοκαίρι του 2023 οι δασικές πυρκαγιές στην Ευρώπη προκάλεσαν υλικές ζημιές ύψους 4,1 δισεκατομμυρίων ευρώ – περισσότερο από το ένα τρίτο εξ αυτών στην Ελλάδα, όπου οι ζημιές κοστολογούνται στα 1,66 δισεκατομμύρια ευρώ. Ακόμα, ο οίκος αξιολόγησης υπολογίζει πως από το 2026 έως το 2050 το ετήσιο κόστος των δασικών πυρκαγιών για την Ελλάδα θα ανέβει στα 2,8 δισεκατομμύρια ευρώ. Παρόμοιες είναι οι προβλέψεις και της σχετικής μελέτης της Τράπεζας της Ελλάδας για τις οικονομικές επιπτώσεις της κλιματικής αλλαγής. Και σε αυτούς τους αριθμούς δεν συνυπολογίζονται καν οι οικολογικές συνέπειες των πυρκαγιών. Οι πυρκαγιές δεν αποτελούν το μοναδικό κλιματικό πρόβλημα της χώρας. «Ηδη βιώνουμε ανά πέντε χρόνια πλημμύρες που θα έπρεπε να συμβαίνουν μία φορά στα 50 χρόνια», εξηγεί ο Κωνσταντίνος Συνολάκης, καθηγητής του Πανεπιστημίου της Νότιας Καλιφόρνιας και πρόεδρος της Εθνικής Επιτροπής για την Κλιματική Αλλαγή. «Επιπλέον, η θερμοκρασία στον μεσογειακό χώρο ανεβαίνει κατά 20% ταχύτερα σε σχέση με τον υπόλοιπο κόσμο». Οι πλημμύρες έχουν και αυτές τεράστιες οικονομικές επιπτώσεις. «Στη Θεσσαλία η κακοκαιρία Ντάνιελ άφησε στα χωράφια ένα στρώμα λάσπης πάχους ενός μέτρου – αχρηστεύοντας έτσι τις καλλιεργήσιμες αυτές εκτάσεις σε βάθος ετών», συνεχίζει η Handelsblatt. «Ο πρωθυπουργός Κυριάκος Μητσοτάκης εκτιμά την οικονομική ζημία στα 3,3 δισεκατομμύρια ευρώ – ή αλλιώς στο 1,7% του ΑΕΠ. 400 εκατομμύρια κοστίζει μόνο η ανακατασκευή των κατεστραμμένων σιδηροδρομικών γραμμών». Η κλιματική αλλαγή επηρεάζει φυσικά και τον τουρισμό, διότι «αφ’ ενός μεν οι ταξιδιώτες προσπαθούν να αποφύγουν ολοένα και περισσότερο τα συχνότερα και μεγαλύτερης διάρκειας κύματα καύσωνα, αφ’ ετέρου δε μέσα στα επόμενα χρόνια θα ανέβει κι άλλο η στάθμη της θάλασσας, με αποτέλεσμα ορισμένες παραλίες να εξαφανιστούν. Τα τελευταία 30 χρόνια η Ελλάδα έχει χάσει ήδη 680 τετραγωνικά χιλιόμετρα από τις αμμουδερές παραλίες της, αναφέρει ο κ. Συνολάκης λαμβάνοντας υπόψιν στοιχεία από το Κοινό Κέντρο Ερευνών της ΕΕ για τη διάβρωση των ακτών. Αυτό μεταφράζεται σε ετήσιες απώλειες εσόδων ύψους 2,6 δισεκατομμυρίων ευρώ από την εκμετάλλευση των παραλιών, σύμφωνα με τον ειδικό». Η Ελλάδα πρόκειται να δαπανήσει εκατοντάδες δισεκατομμύρια ευρώ για την αντιμετώπιση των επιπτώσεων της κλιματικής αλλαγής μέσα στις επόμενες δεκαετίες. Ακόμα κι έτσι όμως, «το εναλλακτικό σενάριο θα ήταν πολύ πιο κοστοβόρο κατά τον ερευνητή του κλίματος Χρήστο Ζερεφό: «Αν δεν κάνουμε τίποτα, το κόστος θα ξεπεράσει τα 700 δισεκατομμύρια ευρώ έως το τέλος του αιώνα» – ένα ποσό διπλάσιο του ελληνικού δημοσίου χρέους». Πηγή Deutsche Welle Φωτιά στη Ρόδο: Νέα εστία σε απόσταση 2 χιλιομέτρωνΗ νέα πυρκαγιά ελέγχθηκε άμεσα ενώ για το περιστατικό έχει επιληφθεί η ΕΛ.ΑΣ. και το ανακριτικό τμήμα του Πυροσβεστικού ΣώματοςΤην ώρα που βρισκόταν σε εξέλιξη η επιχείρηση κατάσβεσης της δασικής φωτιάς στην περιοχή Μονόλιθος στη Ρόδο, μια νέα πυρκαγιά έγινε αντιληπτή, σε απόσταση περίπου δύο χιλιομέτρων από το αρχικό μέτωπο. Σύμφωνα με πληροφορίες, η νέα αυτή εστία, η οποία εντοπίστηκε λίγο μετά τις 7.30 το απόγευμα, ελέγχθηκε άμεσα, ενώ για το π ...

# %%
wordcloud = WordCloud(
    stopwords = STOPWORDS,
    width = 2000,
    height = 1000,
    background_color = 'black'
 ).generate(aug_text)
fig = plt.figure(
    figsize = (40, 30),
    facecolor = 'k',
    edgecolor = 'k')
plt.imshow(wordcloud, interpolation = 'bilinear')
plt.axis('off')
plt.tight_layout(pad=0)
plt.show()

# %%
list(STOPWORDS)[0:20]
# Out:
# ['being',
#  'also',
#  'each',
#  'all',
#  "who's",
#  'after',
#  'few',
#  'once',
#  'am',
#  "didn't",
#  'or',
#  "i've",
#  'its',
#  'only',
#  'such',
#  'of',
#  "wasn't",
#  "i'm",
#  'r',
#  'be']

# %%
import spacy

# %%
# !python -m spacy download el_core_news_sm
# Out:
# Collecting el-core-news-sm==3.8.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/el_core_news_sm-3.8.0/el_core_news_sm-3.8.0-py3-none-any.whl (12.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.6/12.6 MB 19.1 MB/s eta 0:00:00
# Installing collected packages: el-core-news-sm
# Successfully installed el-core-news-sm-3.8.0
# ✔ Download and installation successful
# You can now load the package via spacy.load('el_core_news_sm')
# ⚠ Restart to reload dependencies
# If you are in a Jupyter or Colab notebook, you may need to restart Python in
# order to load all the package's dependencies. You can do this by selecting the
# 'Restart kernel' or 'Restart runtime' option.

# %%
nlp = spacy.load('el_core_news_sm')

# %%
print(sorted(nlp.Defaults.stop_words)[0:20])
# Out:
# ['άλλα', 'άλλες', 'άλλη', 'άλλην', 'άλλης', 'άλλο', 'άλλοι', 'άλλον', 'άλλος', 'άλλοτε', 'άλλους', 'άλλων', 'άμα', 'άμεσα', 'άνευ', 'άνω', 'άξαφνα', 'άρα', 'άραγε', 'έγιναν']

# %%
def create_wordcloud(text):
  wordcloud = WordCloud(
      stopwords = nlp.Defaults.stop_words,
      width = 2000,
      height = 1000,
      background_color = 'black'
  ).generate(text)
  return wordcloud

# %%
wcloud = create_wordcloud(aug_text)
list(wcloud.words_.items())[:5]
# Out:
# [('περιοχή', 1.0),
#  ('πυρκαγιά', 0.8640776699029126),
#  ('πυρκαγιές', 0.8592233009708737),
#  ('σύμφωνα', 0.8398058252427184),
#  ('φωτιά', 0.7912621359223301)]

# %%
def create_wordcloud_img(text):
  wordcloud = create_wordcloud(text)
  fig = plt.figure(
      figsize = (40, 30),
      facecolor = 'k',
      edgecolor = 'k')
  return plt.imshow(wordcloud)

# %%
create_wordcloud_img(aug_text)

# %%
nlp.Defaults.stop_words.add("πυρκαγιές")
print(nlp.vocab['πυρκαγιές'].is_stop)
# Out:
# True

# %%
nlp.Defaults.stop_words.add("πυρκαγιά")
nlp.Defaults.stop_words.add("φωτιές")
nlp.Defaults.stop_words.add("φωτιά")
nlp.Defaults.stop_words.add("δασικές")
nlp.Defaults.stop_words.add("πυρκαγιών")
nlp.Defaults.stop_words.add("Κ")
nlp.Defaults.stop_words.add("πυρκαγιάς")

# %%
create_wordcloud_img(aug_text)

# %%
aug_text_lower = aug_text.lower()
create_wordcloud_img(aug_text_lower)

# %%
aug_text_doc = nlp(aug_text_lower)
for token in aug_text_doc[:10]:
    print(f"{token.text} -> {token.lemma_} ({token.pos_})")
# Out:
# handelsblatt -> handelsblatt (X)
# : -> : (PUNCT)
# ζημιές -> ζημιά (NOUN)
# δισεκατομμυρίων -> δισεκατομμύριο (NOUN)
# στην -> σε ο (ADP)
# ελλάδα -> Ελλάδα (PROPN)
# λόγω -> λόγω (ADP)
# της -> ο (DET)
# κλιματικής -> κλιματική (NOUN)
# κρίσης«μετά -> κρίσης«μετά (ADP)

# %%
tokenized_aug_text_doc = ' '.join(token.lemma_ for token in aug_text_doc)

# %%
print(aug_text[:200])
print(tokenized_aug_text_doc[:200])
# Out:
# Handelsblatt: Ζημιές δισεκατομμυρίων στην Ελλάδα λόγω της κλιματικής κρίσης«Μετά την κρίση χρέους η Ελλάδα απειλείται τώρα από την κλιματική κρίση», γράφει η οικονομική επιθεώρηση Handelsblatt. Και μί
# handelsblatt : ζημιά δισεκατομμύριο σε ο Ελλάδα λόγω ο κλιματική κρίσης«μετά ο κρίση χρέος ο Ελλάδα απειλείται τώρα από ο κλιματικός κρίση » , γράφω ο οικονομικός επιθεώρηση handelsblatt . και ένας τέ

# %%
create_wordcloud_img(tokenized_aug_text_doc)

# %%
nlp.Defaults.stop_words.add("πυρκαγιάς σήμερα")
nlp.Defaults.stop_words.add("πυρκαγία")
nlp.Defaults.stop_words.add("πυρκαγιών")
nlp.Defaults.stop_words.add("πυρκαγιός")
nlp.Defaults.stop_words.add("κίνδυνος πυρκαγιάς")
create_wordcloud_img(tokenized_aug_text_doc)

# %%
wordcloud = create_wordcloud(tokenized_aug_text_doc)
frequencies = wordcloud.words_
print(frequencies)
# Out:
# {'περιοχή': 1.0, 'δασικός': 0.6208530805687204, 'μεγάλος': 0.6113744075829384, 'πολύς': 0.48104265402843605, 'σύμφωνα': 0.4099526066350711, 'μπορώ': 0.4052132701421801, 'χώρα': 0.3909952606635071, 'υπάρχω': 0.3578199052132701, 'γίνομαι': 0.3412322274881517, 'πυροσβεστικός': 0.2962085308056872, 'κάνω': 0.28199052132701424, 'χρόνος': 0.2725118483412322, 'αναφέρω': 0.26303317535545023, 'πυροσβέστης': 0.26303317535545023, 'πολιτικός προστασία': 0.25118483412322273, 'Ελλάδα': 0.24881516587677724, 'ή': 0.24881516587677724, 'αττικός': 0.24644549763033174, 'στρέμματα': 0.2156398104265403, 'βρίσκω': 0.2132701421800948, 'αλεξανδρούπολη': 0.2109004739336493, 'όχημα': 0.20616113744075829, 'δύο': 0.2037914691943128, 'σήμερα': 0.1848341232227488, 'επιχειρώ': 0.17535545023696683, 'ώς': 0.17061611374407584, 'δάσος': 0.17061611374407584, 'αρχή': 0.17061611374407584, 'λέγω': 0.16587677725118483, 'χθες': 0.16350710900473933, 'ημέρα': 0.16113744075829384, 'τονίζω': 0.15639810426540285, 'αυγούστου': 0.15402843601895735, 'κυβέρνηση': 0.14928909952606634, 'ξεκινώ': 0.14928909952606634, 'κλιματικός κρίση': 0.14928909952606634, 'στοιχείο': 0.14691943127962084, 'μέτωπο': 0.14691943127962084, 'πόλη': 0.14691943127962084, 'κάτοικος': 0.14454976303317535, 'νέος': 0.13981042654028436, 'σημειώνω': 0.13744075829383887, 'δήμος': 0.13744075829383887, 'συνεχίζω': 0.13507109004739337, 'φορά': 0.13270142180094788, 'ώρα': 0.13270142180094788, 'αφορώ': 0.13270142180094788, 'έτος': 0.13033175355450238, 'δύναμη': 0.13033175355450238, 'θερμοκρασία': 0.12796208530805686, 'διάρκεια': 0.12796208530805686, 'έργο': 0.12796208530805686, 'πρωθυπουργός': 0.12559241706161137, 'αναζωπυρώσεις': 0.12559241706161137, 'ομάδα': 0.12322274881516587, 'έκταση': 0.12322274881516587, 'υπηρεσία': 0.12322274881516587, 'άνθρωπος': 0.12085308056872038, 'εβρος': 0.12085308056872038, 'περίπτωση': 0.11611374407582939, 'καταστροφή': 0.11374407582938388, 'σημείο': 0.11374407582938388, 'δύσκολος': 0.11374407582938388, 'νησί': 0.11374407582938388, 'αντιμετωπίζω': 0.10900473933649289, 'εβρο': 0.10900473933649289, 'εξέλιξη': 0.1066350710900474, 'διαχείριση': 0.1066350710900474, 'σπίτι': 0.10426540284360189, 'πρόληψη': 0.10426540284360189, 'συνθήκη': 0.10426540284360189, 'ισπανία': 0.10426540284360189, 'είδος': 0.1018957345971564, 'κατάσταση': 0.1018957345971564, 'μέρα': 0.1018957345971564, 'πρόεδρος': 0.0995260663507109, 'περίοδος': 0.0995260663507109, 'μήνας': 0.0971563981042654, 'πρόβλημα': 0.0971563981042654, 'πολίτης': 0.0971563981042654, 'μάχη': 0.0971563981042654, 'τέλος': 0.0947867298578199, 'συνολικά': 0.0947867298578199, 'φτάνω': 0.0947867298578199, 'τρίτος': 0.0924170616113744, 'μέτρο': 0.0924170616113744, 'παραμένω': 0.0924170616113744, 'εθελοντής': 0.0924170616113744, 'οικισμός': 0.0924170616113744, 'προκαλώ': 0.0924170616113744, 'δαδιά': 0.0924170616113744, 'εξηγώ': 0.09004739336492891, 'νερό': 0.09004739336492891, 'προστασία': 0.09004739336492891, 'δεύτερος': 0.09004739336492891, 'καεί': 0.09004739336492891, 'θέλω': 0.09004739336492891, 'δημιουργώ': 0.09004739336492891, 'στιγμή': 0.09004739336492891, 'κλιματικός αλλαγή': 0.09004739336492891, 'δασικός υπηρεσία': 0.09004739336492891, 'σημαντικός': 0.08767772511848342, 'ζήτημα': 0.08767772511848342, 'βάση': 0.08767772511848342, 'δηλώνω': 0.08767772511848342, 'αποτέλεσμα': 0.08530805687203792, 'αντιμετώπιση': 0.08530805687203792, 'μιλώ': 0.08530805687203792, 'βράδυ': 0.08530805687203792, 'πάρνηθα': 0.08530805687203792, 'πυροσβεστικός δύναμη': 0.08530805687203792, 'εκ': 0.08293838862559241, 'πληροφορία': 0.08293838862559241, 'πολιτική': 0.08293838862559241, 'φλόγος': 0.08293838862559241, 'άνεμος': 0.08293838862559241, 'λέει': 0.08293838862559241, 'διαφορετικός': 0.08293838862559241, 'κράτος': 0.08056872037914692, 'επίπτωση': 0.08056872037914692, 'αεροσκάφος': 0.08056872037914692, 'σύσκεψη': 0.08056872037914692, 'ανάγκη': 0.08056872037914692, 'μέρος': 0.08056872037914692, 'χρειάζομαι': 0.08056872037914692, 'λόγος': 0.08056872037914692, 'δίνω' ...

# %%
wc_df = pd.DataFrame(frequencies.items(), columns=["λέξη", "σχετική συχνότητα"])
wc_df
# Out:
#            λέξη  σχετική συχνότητα
# 0       περιοχή           1.000000
# 1       δασικός           0.620853
# 2       μεγάλος           0.611374
# 3         πολύς           0.481043
# 4       σύμφωνα           0.409953
# ..          ...                ...
# 195     ξέσπασε           0.061611
# 196   πρόγραμμα           0.061611
# 197  δυνατότητα           0.061611
# 198      οδηγία           0.061611
# 199     καναδάς           0.061611
#
# [200 rows x 2 columns]

# %%
aug_text_doc.ents
# Out:
# (ελλάδα,
#  ελλάδα,
#  ελλάδα,
#  ελλάδα,
#  ευρώπη,
#  ελλάδα,
#  ελλάδα,
#  ελλάδας,
#  ελλάδα,
#  ελλάδα,
#  μεσογείου,
#  μητσοτάκης,
#  μητσοτάκης,
#  μητσοτάκη,
#  συριζα,
#  συριζα,
#  συριζα,
#  ιδιοκτήτη,
#  κ.μητσοτάκης,
#  μητσοτάκης,
#  χαλάνδρι,
#  ηπα,
#  ευρώπη,
#  ηπα,
#  ηπα,
#  ηπα,
#  ελλάδα,
#  σχήμα,
#  ιταλία,
#  ευρώπη,
#  ισπανία,
#  ν.δ,
#  ε.ε,
#  συριζα,
#  συριζα,
#  συριζα,
#  συριζα,
#  the flame,
#  ευρώπη,
#  μεσογείου,
#  κρήτη,
#  ελλάδα,
#  ελλάδα,
#  ελλάδα,
#  ελλάδα,
#  ελλάδα,
#  αριανούτσου,
#  αριανούτσου,
#  συριζα,
#  ελλάδα,
#  ελλάδας,
#  facebook meteo,
#  συριζα,
#  ελλάδας,
#  κομισιόν,
#  ιταλία,
#  κομισιόν,
#  ελλάδας,
#  κομισιόν,
#  ιταλία,
#  ελλάδα,
#  ελλάδα,
#  ιταλία,
#  ιταλία,
#  γαλλία,
#  ελλάδα,
#  ελλάδα,
#  thick smoke,
#  live-blogging,
#  ελλάδα,
#  ελλάδα,
#  κρήτη,
#  ευρωπαϊκό,
#  ελλάδα,
#  κρήτη –,
#  #,
#  #,
#  #,
#  #,
#  νίκος χαλκιαδάκης,
#  ευρωπαϊκό ινστιτούτο,
#  ελλάδα,
#  ιαπωνία,
#  ευρώπη,
#  ευρώπη,
#  πακιστάν,
#  ηπα,
#  ελλάδα,
#  ελλάδα,
#  ελλάδα,
#  ισπανία,
#  ιταλία,
#  ελλάδα,
#  ισπανία,
#  ελλάδα,
#  ελλάδα,
#  ιταλία,
#  κυριάκου μητσοτάκη,
#  εκαβ,
#  ερτ,
#  #,
#  ισπανία,
#  γαλλία,
#  ισπανία,
#  ιταλία,
#  γαλλία,
#  ισπανία,
#  ιταλία,
#  ισπανία,
#  the 2006-2022,
#  forest fire,
#  #,
#  #,
#  μητσοτάκης,
#  ισπανία,
#  ελλάδα,
#  συριζα,
#  μητσοτάκης,
#  μητσοτάκης,
#  συριζα,
#  μητσοτάκης,
#  νίκος ανδρουλάκης,
#  ανδρουλάκης,
#  μητσοτάκης,
#  συριζα,
#  ελλάδα,
#  νίκος ανδρουλάκης,
#  ελλάδα,
#  ανδρουλάκης,
#  νίκος ανδρουλάκης,
#  ανδρουλάκης,
#  μητσοτάκης,
#  νίκος ανδρουλάκης,
#  μητσοτάκης,
#  ανδρουλάκης,
#  συριζα,
#  νίκος ανδρουλάκης,
#  ανδρουλάκης,
#  νίκος ανδρουλάκης,
#  συριζα,
#  συριζα,
#  ευρώπης,
#  ελλάδας,
#  ευρώπης,
#  ευρώπη,
#  συριζα,
#  συριζα,
#  μητσοτάκη,
#  μητσοτάκης,
#  ελλάδα,
#  ελλάδα,
#  ελλάδα,
#  ελλάδα,
#  συριζα,
#  συριζα,
#  ελλάδα,
#  ευρώπης,
#  συριζα,
#  νίκος ανδρουλάκης,
#  ευρώπη,
#  ευρώπη,
#  ερτ,
#  θεσσαλονίκης,
#  γερμανία,
#  γαλλία,
#  γερμανία,
#  γαλλία,
#  αφρική,
#  αφρική,
#  αφρική,
#  πακιστάν,
#  m3 –,
#  m3,
#  ινδίας,
#  m3,
#  ευρώπη,
#  ελλάδα,
#  πελοποννήσου,
#  ερτ,
#  ερτ,
#  γερμανία,
#  σουηδία,
#  ερτ,
#  #,
#  #,
#  #,
#  #,
#  ελλάδα,
#  ισπανία,
#  ιταλία,
#  ελλάδα,
#  ελλάδα,
#  ελλάδα,
#  ελλάδα,
#  ισπανία,
#  π.ε,
#  ελλάδα,
#  ελλάδα,
#  ισπανία,
#  ιταλία,
#  ελλάδα,
#  ελλάδα,
#  ισπανία,
#  ελλάδα,
#  ελλάδα,
#  ελλάδας,
#  ισπανία,
#  ερτ,
#  ελλάδας,
#  νίκος ανδρουλάκης,
#  κωνσταντοπούλου,
#  ευρωπαϊκό,
#  θεσσαλονίκης,
#  θεσσαλονίκης,
#  ευάγγελος γερασόπουλος,
#  ευρώπη,
#  #,
#  ερτ,
#  μπακογιάννη,
#  ελλάδα,
#  μάλτας,
#  ελλάδα,
#  ελλάδα,
#  πάρινγκτον,
#  ευρώπη,
#  ελλάδα,
#  ερτ,
#  #,
#  τουρκία,
#  μητσοτάκης,
#  μητσοτάκης,
#  ελλάδα,
#  μαρινάκης,
#  μητσοτάκη,
#  πελοποννήσου,
#  μητσοτάκη,
#  σδιτ,
#  ευρώπη,
#  ελλάδα,
#  twitter,
#  ε.ε,
#  ελλάδα,
#  εκαβ,
#  ερτ,
#  ελλάδα,
#  ελλάδα,
#  ελλάδα,
#  ερτ,
#  #,
#  ερτ,
#  meteo,
#  ελλάδας,
#  pic.twitter.com/xzzuufzxaf,
#  ντέιβιντ,
#  τζέισον μπρόλαντ,
#  ελλάδας,
#  #fire #,
#  σέιν τόμσον,
#  #fire,
#  #,
#  μάικ,
#  the stock,
#  twitter,
#  μάικ,
#  ελλάδας,
#  twitter,
#  ελλάδα,
#  ελλάδας,
#  national,
#  ελλάδα,
#  the gross,
#  λονδίνου,
#  μαρκ μάσλιν,
#  ελλάδας,
#  u.s,
#  ηπα,
#  u.s,
#  ευρώπη,
#  ηπα,
#  ευρώπη,
#  αφρική,
#  ευρώπη,
#  ισπανία,
#  ισπανία,
#  οηε,
#  σουηδία,
#  σουηδία,
#  δανία,
#  σουηδία,
#  ισπανία,
#  ισπανία,
#  ισπανία,
#  twitter,
#  twitter,
#  ισπανία,
#  ισπανία,
#  οηε,
#  ελλάδας,
#  ελλάδα,
#  ελλάδα,
#  ελλάδα,
#  ελλάδα,
#  ελλάδα,
#  ελλάδα,
#  απε-μπε,
#  ελλάδα,
#  ελλάδα,
#  ελλάδα,
#  ελλάδα,
#  ευρώπη,
#  ελλάδα,
#  απε-μπε,
#  ελλάδα,
#  ελλάδα,
#  ελλάδα,
#  γερμανία,
#  ελλάδα,
#  ελλάδα,
#  χελντ,
#  european forest institute)μήπως,
#  χελντ,
#  european forest,
#  χελντ,
#  χελντ,
#  ισπανία,
#  ελλάδα,
#  χελντ,
#  ελλάδα,
#  ελλάδα,
#  ελλάδα,
#  ελλάδα,
#  ιταλία,
#  ισπανία,
#  ελλάδα,
#  ιταλία,
#  ισπανία,
#  ιταλία,
#  ελλάδα,
#  ισπανία,
#  νικόλας ματθαίου,
#  παναγιώτη κυζιρίδη,
#  νικόλας ματθαίου,
#  νικόλας ματθαίου,
#  παναγιώτης,
#  ελλάδα,
#  νικόλας ματθαίου,
#  ελλάδα,
#  νικόλας ματθαίου,
#  facebook,
#  πελοποννήσου,
#  ελλάδας,
#  ιταλίας,
#  μάλτας,
#  ελλάδας,
#  ιταλίας,
#  μάλτας,
#  μεσογείου,
#  ευρωπαϊκό,
#  ελλάδα,
#  ε.ε,
#  ε.ε,
#  ελλάδα,
#  ιταλία,
#  ισπανία,
#  ελλάδα,
#  ιταλία,
#  ισπανία,
#  ελλάδα,
#  ιταλία,
#  ελλάδα,
#  ελλάδας,
#  ελλάδα,
#  ελλάδα,
#  meteo.gr,
#  ελλάδα,
#  ελλάδα,
#  μπακαλούδης)

# %%
for ent in aug_text_doc.ents:
  print(ent.text, ent.label_)
# Out:
# ελλάδα GPE
# ελλάδα GPE
# ελλάδα GPE
# ελλάδα GPE
# ευρώπη GPE
# ελλάδα GPE
# ελλάδα GPE
# ελλάδας GPE
# ελλάδα GPE
# ελλάδα GPE
# μεσογείου GPE
# μητσοτάκης PERSON
# μητσοτάκης PERSON
# μητσοτάκη PERSON
# συριζα ORG
# συριζα ORG
# συριζα ORG
# ιδιοκτήτη PERSON
# κ.μητσοτάκης PERSON
# μητσοτάκης PERSON
# χαλάνδρι GPE
# ηπα GPE
# ευρώπη GPE
# ηπα GPE
# ηπα GPE
# ηπα GPE
# ελλάδα GPE
# σχήμα ORG
# ιταλία GPE
# ευρώπη GPE
# ισπανία GPE
# ν.δ ORG
# ε.ε ORG
# συριζα ORG
# συριζα ORG
# συριζα ORG
# συριζα ORG
# the flame ORG
# ευρώπη GPE
# μεσογείου GPE
# κρήτη GPE
# ελλάδα GPE
# ελλάδα GPE
# ελλάδα GPE
# ελλάδα GPE
# ελλάδα GPE
# αριανούτσου PERSON
# αριανούτσου PERSON
# συριζα ORG
# ελλάδα GPE
# ελλάδας GPE
# facebook meteo ORG
# συριζα ORG
# ελλάδας GPE
# κομισιόν ORG
# ιταλία GPE
# κομισιόν ORG
# ελλάδας GPE
# κομισιόν ORG
# ιταλία GPE
# ελλάδα GPE
# ελλάδα GPE
# ιταλία GPE
# ιταλία GPE
# γαλλία GPE
# ελλάδα GPE
# ελλάδα GPE
# thick smoke PERSON
# live-blogging PERSON
# ελλάδα GPE
# ελλάδα GPE
# κρήτη GPE
# ευρωπαϊκό ORG
# ελλάδα GPE
# κρήτη – GPE
# # GPE
# # ORG
# # GPE
# # GPE
# νίκος χαλκιαδάκης PERSON
# ευρωπαϊκό ινστιτούτο ORG
# ελλάδα GPE
# ιαπωνία GPE
# ευρώπη GPE
# ευρώπη GPE
# πακιστάν GPE
# ηπα GPE
# ελλάδα GPE
# ελλάδα GPE
# ελλάδα GPE
# ισπανία GPE
# ιταλία GPE
# ελλάδα GPE
# ισπανία GPE
# ελλάδα GPE
# ελλάδα GPE
# ιταλία GPE
# κυριάκου μητσοτάκη PERSON
# εκαβ ORG
# ερτ ORG
# # GPE
# ισπανία GPE
# γαλλία GPE
# ισπανία GPE
# ιταλία GPE
# γαλλία GPE
# ισπανία GPE
# ιταλία GPE
# ισπανία GPE
# the 2006-2022 ORG
# forest fire ORG
# # GPE
# # ORG
# μητσοτάκης PERSON
# ισπανία GPE
# ελλάδα GPE
# συριζα ORG
# μητσοτάκης PERSON
# μητσοτάκης PERSON
# συριζα ORG
# μητσοτάκης PERSON
# νίκος ανδρουλάκης PERSON
# ανδρουλάκης PERSON
# μητσοτάκης PERSON
# συριζα ORG
# ελλάδα GPE
# νίκος ανδρουλάκης PERSON
# ελλάδα GPE
# ανδρουλάκης PERSON
# νίκος ανδρουλάκης PERSON
# ανδρουλάκης PERSON
# μητσοτάκης PERSON
# νίκος ανδρουλάκης PERSON
# μητσοτάκης PERSON
# ανδρουλάκης PERSON
# συριζα ORG
# νίκος ανδρουλάκης PERSON
# ανδρουλάκης PERSON
# νίκος ανδρουλάκης PERSON
# συριζα ORG
# συριζα ORG
# ευρώπης GPE
# ελλάδας GPE
# ευρώπης GPE
# ευρώπη GPE
# συριζα ORG
# συριζα ORG
# μητσοτάκη PERSON
# μητσοτάκης PERSON
# ελλάδα GPE
# ελλάδα GPE
# ελλάδα GPE
# ελλάδα GPE
# συριζα ORG
# συριζα ORG
# ελλάδα GPE
# ευρώπης GPE
# συριζα ORG
# νίκος ανδρουλάκης PERSON
# ευρώπη GPE
# ευρώπη GPE
# ερτ ORG
# θεσσαλονίκης GPE
# γερμανία GPE
# γαλλία GPE
# γερμανία GPE
# γαλλία GPE
# αφρική GPE
# αφρική GPE
# αφρική GPE
# πακιστάν GPE
# m3 – PERSON
# m3 ORG
# ινδίας GPE
# m3 ORG
# ευρώπη GPE
# ελλάδα GPE
# πελοποννήσου GPE
# ερτ ORG
# ερτ ORG
# γερμανία GPE
# σουηδία GPE
# ερτ ORG
# # ORG
# # GPE
# # ORG
# # GPE
# ελλάδα GPE
# ισπανία GPE
# ιταλία GPE
# ελλάδα GPE
# ελλάδα GPE
# ελλάδα GPE
# ελλάδα GPE
# ισπανία GPE
# π.ε ORG
# ελλάδα GPE
# ελλάδα GPE
# ισπανία GPE
# ιταλία GPE
# ελλάδα GPE
# ελλάδα GPE
# ισπανία GPE
# ελλάδα GPE
# ελλάδα GPE
# ελλάδας GPE
# ισπανία GPE
# ερτ ORG
# ελλάδας GPE
# νίκος ανδρουλάκης PERSON
# κωνσταντοπούλου PERSON
# ευρωπαϊκό ORG
# θεσσαλονίκης GPE
# θεσσαλονίκης GPE
# ευάγγελος γερασόπουλος PERSON
# ευρώπη GPE
# # ORG
# ερτ ORG
# μπακογιάννη PERSON
# ελλάδα GPE
# μάλτας GPE
# ελλάδα GPE
# ελλάδα GPE
# πάρινγκτον PERSON
# ευρώπη GPE
# ελλάδα GPE
# ερτ ORG
# # GPE
# τουρκία GPE
# μητσοτάκης PERSON
# μητσοτάκης PERSON
# ελλάδα GPE
# μαρινάκης PERSON
# μητσοτάκη PERSON
# πελοποννήσου GPE
# μητσοτάκη PERSON
# σδιτ ORG
# ευρώπη GPE
# ελλάδα GPE
# twitter ORG
# ε.ε ORG
# ελλάδα GPE
# εκαβ ORG
# ερτ ORG
# ελλάδα GPE
# ελλάδα GPE
# ελλάδα GPE
# ερτ ORG
# # GPE
# ερτ ORG
# meteo GPE
# ελλάδας GPE
# pic.twitter.com/xzzuufzxaf ORG
# ντέιβιντ PERSON
# τζέισον μπρόλαντ PERSON
# ελλάδας GPE
# #fire # ORG
# σέιν τόμσον PERSON
# #fire EVENT
# # GPE
# μάικ PERSON
# the stock ORG
# twitter ORG
# μάικ PERSON
# ελλάδας GPE
# twitter ORG
# ελλάδα GPE
# ελλάδας GPE
# national PERSON
# ελλάδα GPE
# the gross ORG
# λονδίνου GPE
# μαρκ μάσλιν PERSON
# ελλάδας GPE
# u.s ORG
# ηπα GPE
# u.s ORG
# ευρώπη GPE
# ηπα GPE
# ευρώπη GPE
# αφρική GPE
# ευρώπη GPE
# ισπανία GPE
# ισπανία GPE
# οηε ORG
# σουηδία GPE
# σουηδία GPE
# δανία GPE
# σουηδία GPE
# ισπανία GPE
# ισπανία GPE
# ισπανία GPE
# twitter ORG
# twitter PRODUCT
# ισπανία GPE
# ισπανία GPE
# οηε ORG
# ελλάδας GPE
# ελλάδα GPE
# ελλάδα GPE
# ελλάδα GPE
# ελλάδα GPE
# ελλάδα GPE
# ελλάδα GPE
# απε-μπε ORG
# ελλάδα GPE
# ελλάδα GPE
# ελλάδα GPE
# ελλάδα GPE
# ευρώπη GPE
# ελλάδα GPE
# απε-μπε ORG
# ελλάδα GPE
# ελλάδα GPE
# ελλάδα GPE
# γερμανία GPE
# ελλάδα GPE
# ελλάδα GPE
# χελντ PERSON
# european forest institute)μήπως ORG
# χελντ PERSON
# european forest PERSON
# χελντ PERSON
# χελντ PERSON
# ισπανία GPE
# ελλάδα GPE
# χελντ PERSON
# ελλάδα GPE
# ελλάδα GPE
# ελλάδα GPE
# ελλάδα GPE
# ιταλία GPE
# ισπανία GPE
# ελλάδα GPE
# ιταλία GPE
# ισπανία GPE
# ιταλία GPE
# ελλάδα GPE
# ισπανία GPE
# νικόλας ματθαίου PERSON
# παναγιώτη κυζιρίδη PERSON
# νικόλας ματθαίου PERSON
# νικόλας ματθαίου PERSON
# παναγιώτης PERSON
# ελλάδα GPE
# νικόλας ματθαίου PERSON
# ελλάδα GPE
# νικόλας ματθαίου PERSON
# facebook ORG
# πελοποννήσου GPE
# ελλάδας GPE
# ιταλίας GPE
# μάλτας GPE
# ελλάδας GPE
# ιταλίας GPE
# μάλτας GPE
# μεσογείου GPE
# ευρωπαϊκό ORG
# ελλάδα GPE
# ε.ε ORG
# ε.ε ORG
# ελλάδα GPE
# ιταλία GPE
# ισπανία GPE
# ελλάδα GPE
# ιταλία GPE
# ισπανία GPE
# ελλάδα GPE
# ιταλία GPE
# ελλάδα GPE
# ελλάδας GPE
# ελλάδα GPE
# ελλάδα GPE
# meteo.gr ORG
# ελλάδα GPE
# ελλάδα GPE
# μπακαλούδης PERSON
